# %%
text= "I bought a computer."

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
text_lower= text.lower()

print(text_lower)
# Out:
# i bought a computer.

# %%
tokens = word_tokenize(text_lower)
print(tokens)
# Out:
# ['i', 'bought', 'a', 'computer', '.']

# %%
text_clean = []
for word in tokens:
    if word not in string.punctuation:
        text_clean.append(word)
print(text_clean)
# Out:
# ['i', 'bought', 'a', 'computer']

# %%
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(tok, pos="v") for tok in text_clean]
print(lemmas)
# Out:
# ['i', 'buy', 'a', 'computer']

# %%
[(token, lemma) for token, lemma in zip(tokens, lemmas)]
# Out:
# [('i', 'i'), ('bought', 'buy'), ('a', 'a'), ('computer', 'computer')]

# %%
morphological_info = {}
for token, lemma in zip(tokens, lemmas):
  if token != lemma:
    if token.endswith("ing"):
      analysis = "Inflectional: Present participle/continous form of {}".format(lemma)
    elif token.endswith("er" or "ation"):
      analysis = 'Derivationall: "{}" + -er -> person who does the action'.format(lemma)
    else:
      analysis = "Inflectional or irregular form of '{}' ".format(lemma)

  else:
    analysis = "Base/root form"

  morphological_info[token] = analysis

# %%
morphological_info
# Out:
# {'i': 'Base/root form',
#  'bought': "Inflectional or irregular form of 'buy' ",
#  'a': 'Base/root form',
#  'computer': 'Base/root form'}
